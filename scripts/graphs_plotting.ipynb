# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %%
os.chdir('../performance_results')
root = os.getcwd()
root
# Out:
# 'c:\\Projects\\TrafficAssignmentApproaches\\performance_results'

# %%
def get_dataset_info(dataset_name):
    os.chdir(dataset_name)
    csv_files = [file for file in os.listdir() if file.endswith('.csv')]
    dataframes = []
    approaches = []
    for file in csv_files:
        approaches.append(file[:-4])
        df = pd.read_csv(file)
        dataframes.append(df)
    os.chdir('..')
    return [dataframes, approaches]

# %%
dataframes, approaches = get_dataset_info('SiouxFalls')

# %%
dataframes[0]
# Out:
#           RGAP  Objective Function    Time
# 0     0.402005         5468620.000   0.005
# 1     0.320295         5237589.418   0.009
# 2     0.256275         4896889.942   0.014
# 3     0.221270         4807484.043   0.019
# 4     0.179347         4679517.696   0.024
# ...        ...                 ...     ...
# 4466  0.000130         4231633.207  23.636
# 4467  0.000123         4231633.116  23.642
# 4468  0.000127         4231633.078  23.648
# 4469  0.000128         4231632.999  23.653
# 4470  0.000126         4231632.931  23.660
#
# [4471 rows x 3 columns]

# %%
approaches

# %%
def plot_datasets_graphs(dataframes, approaches):
    for [df, name] in zip(dataframes, approaches):
        plt.plot(df["Time"], df["RGAP"], label = name)
    plt.legend()
    plt.yscale('log')
    plt.grid(axis='x', which='major')
    plt.grid(axis='y', which='major')
    plt.yticks([10 ** i for i in range(-18, 0, 3)])
    plt.xlabel('sec')
    plt.ylabel('RGAP')
    plt.show()

# %%
plot_datasets_graphs(*get_dataset_info('SiouxFalls'))

# %%
dataframes, approaches = get_dataset_info('SiouxFalls')
plot_datasets_graphs(*get_dataset_info('SiouxFalls'))

# %%
dataframes, approaches = get_dataset_info('Barcelona')
plot_datasets_graphs(*get_dataset_info('Barcelona'))
